# %% [markdown]
# # <center>Car Dataset</center>

# %% [markdown]
# ### Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Initializing the dataframe

# %%
df = pd.read_csv('CarPrice.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber
# 0       1          3        alfa-romero giulia      gas        std        two  \
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize
# 0  convertible        rwd          front       88.6  ...         130  \
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe(include='O')
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel
# count             205      205        205        205     205        205  \
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000  \
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio
# count   205.000000  205.000000  205.000000  205.000000        205.000000  \
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.shape
# Out:
# (205, 26)

# %% [markdown]
# #### Checking the skewness of the dataframe

# %%
df.select_dtypes(include='number').skew()
# Out:
# car_ID              0.000000
# symboling           0.211072
# wheelbase           1.050214
# carlength           0.155954
# carwidth            0.904003
# carheight           0.063123
# curbweight          0.681398
# enginesize          1.947655
# boreratio           0.020156
# stroke             -0.689705
# compressionratio    2.610862
# horsepower          1.405310
# peakrpm             0.075159
# citympg             0.663704
# highwaympg          0.539997
# price               1.777678
# dtype: float64

# %% [markdown]
# Clearly, compressionratio, horsepower, price and enginesize are highly positively skewed.
# wheelbase, carwidth, curbweight and citympg are moderately positively skewed.
# stroke is moderately negatively skewed.

# %% [markdown]
# #### Que #1: If i choose a car randomly, what is the probability that it is a Sedan?

# %%
df['carbody'].value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
E = df['carbody'].value_counts()['sedan']
S = df['carbody'].value_counts().sum()
P = round(E/S, 4)
print("The probability that I get a Sedan when choosen randomly is", P)
# Out:
# The probability that I get a Sedan when choosen randomly is 0.4683

# %% [markdown]
# #### Que #2: What is the probability that the car choosen randomly is Sedan and has fuel type as Gas(petrol)?

# %%
crosstab = pd.crosstab(df['carbody'], df['fueltype'], margins=True)
crosstab
# Out:
# fueltype     diesel  gas  All
# carbody
# convertible       0    6    6
# hardtop           1    7    8
# hatchback         1   69   70
# sedan            15   81   96
# wagon             3   22   25
# All              20  185  205

# %%
E = crosstab.loc['sedan', 'gas']
S = len(df)
P = round(E/S, 4)
print("The probability that I get a Sedan which uses Fuel when choosen randomly is", P)
# Out:
# The probability that I get a Sedan which uses Fuel when choosen randomly is 0.3951

# %% [markdown]
# #### Que #3: What is the probability that a car is Sedan, given it is a fuel type?

# %%
crosstab = pd.crosstab(df['carbody'], df['fueltype'], margins=True)
crosstab
# Out:
# fueltype     diesel  gas  All
# carbody
# convertible       0    6    6
# hardtop           1    7    8
# hatchback         1   69   70
# sedan            15   81   96
# wagon             3   22   25
# All              20  185  205

# %%
# P(S|F) = P(S n F) / P(F)
pSnF = crosstab.loc['sedan', 'gas']
pF = len(df[df['fueltype'] == 'gas'])
pS_F = round(pSnF / pF, 4)

print("The probability that I get a Sedan given it uses Gas is", pS_F)
# Out:
# The probability that I get a Sedan given it uses Gas is 0.4378
